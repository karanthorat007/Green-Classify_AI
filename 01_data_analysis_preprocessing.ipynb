# %% [markdown]
# 🔹 Cell 1: Imports

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# 🔹 Cell 2: Dataset Paths

# %%
BASE_DIR = os.environ.get("DATASET_DIR", "dataset")
TRAIN_DIR = os.path.join(BASE_DIR, "train")
VAL_DIR = os.path.join(BASE_DIR, "validation")
TEST_DIR = os.path.join(BASE_DIR, "test")

print("Train Path:", TRAIN_DIR)
print("Validation Path:", VAL_DIR)
print("Test Path:", TEST_DIR)

if not os.path.isdir(TRAIN_DIR):
    print("\nDataset not found.")
    print("Place data at <repo>/dataset/train or set DATASET_DIR to your dataset folder.")
# Out:
# Train Path: dataset\train
# Validation Path: dataset\validation
# Test Path: dataset\test
#
# Dataset not found.
# Place data at <repo>/dataset/train or set DATASET_DIR to your dataset folder.

# %% [markdown]
# 🔹 Cell 3: Class Names

# %%
if not os.path.isdir(TRAIN_DIR):
    raise FileNotFoundError(
        f"Train directory not found: {os.path.abspath(TRAIN_DIR)}\n"
        "Set DATASET_DIR or create dataset/train."
    )

classes = sorted(os.listdir(TRAIN_DIR))
num_classes = len(classes)

print("Classes:")
for cls in classes:
    print("-", cls)

print("\nTotal classes:", num_classes)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 if not os.path.isdir(TRAIN_DIR):
# ----> 2     raise FileNotFoundError(
#       3         f"Train directory not found: {os.path.abspath(TRAIN_DIR)}\n"
#       4         "Set DATASET_DIR or create dataset/train."
#       5     )
#       7 classes = sorted(os.listdir(TRAIN_DIR))
#       8 num_classes = len(classes)
#
# FileNotFoundError: Train directory not found: d:\Data science\GreenClassify-main\dataset\train
# Set DATASET_DIR or create dataset/train.

# %% [markdown]
# 🔹 Cell 4: Images Count Per Class

# %%
def count_images(folder):
    data = {}
    for cls in os.listdir(folder):
        class_path = os.path.join(folder, cls)
        data[cls] = len(os.listdir(class_path))
    return data

train_count = count_images(TRAIN_DIR)
val_count = count_images(VAL_DIR)
test_count = count_images(TEST_DIR)

print("Train Images:", train_count)
print("Validation Images:", val_count)
print("Test Images:", test_count)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 8
#       5         data[cls] = len(os.listdir(class_path))
#       6     return data
# ----> 8 train_count = count_images(TRAIN_DIR)
#       9 val_count = count_images(VAL_DIR)
#      10 test_count = count_images(TEST_DIR)
#
# Cell In[9], line 3, in count_images(folder)
#       1 def count_images(folder):
#       2     data = {}
# ----> 3     for cls in os.listdir(folder):
#       4         class_path = os.path.join(folder, cls)
#       5         data[cls] = len(os.listdir(class_path))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'dataset\\train'

# %% [markdown]
# 🔹 Cell 5: Visualize Class Distribution

# %%
plt.figure(figsize=(12,5))
plt.bar(train_count.keys(), train_count.values())
plt.xticks(rotation=90)
plt.title("Training Dataset Distribution")
plt.show()

# %% [markdown]
# 🔹 Cell 6: Sample Image Visualization

# %%
plt.figure(figsize=(10,10))

for i, cls in enumerate(classes[:9]):
    img_path = os.path.join(TRAIN_DIR, cls, os.listdir(os.path.join(TRAIN_DIR, cls))[0])
    img = Image.open(img_path)
    
    plt.subplot(3,3,i+1)
    plt.imshow(img)
    plt.title(cls)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# 🔹 Cell 7: Preprocessing Parameters

# %%
IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 32

print("Image size:", IMG_HEIGHT, "x", IMG_WIDTH)
print("Batch size:", BATCH_SIZE)
# Out:
# Image size: 224 x 224
# Batch size: 32
